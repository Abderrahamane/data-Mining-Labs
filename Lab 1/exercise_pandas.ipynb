# %%
# Importing Pandas
import pandas as pd
import numpy as np

# %%
# Create a DataFrame from the given data
data = {
    'Name': ['Amine', 'Imene', 'Yacine', 'Sarah', 'Redha'],
    'Age': [np.nan, 30, 22, 35, 28],
    'City': ['Alger', 'Setif', 'Oran', 'Annaba', 'Jijel'],
    'Salary': [50000, 70000, 60000, 80000, 55000]
}

df = pd.DataFrame(data)

# %%
# 1. Display the first 3 rows of the DataFrame
first_3_rows = df.head(3)
print("1. Display the first 3 rows of the DataFrame:\n", first_3_rows)
# Out:
# 1. Display the first 3 rows of the DataFrame:
#       Name   Age   City  Salary
# 0   Amine   NaN  Alger   50000
# 1   Imene  30.0  Setif   70000
# 2  Yacine  22.0   Oran   60000

# %%
# 2. Find the number of rows and columns in the DataFrame
shape_of_df = df.shape
print("2. Find the number of rows and columns in the DataFrame:\n", shape_of_df)
# Out:
# 2. Find the number of rows and columns in the DataFrame:
#  (5, 4)

# %%
# 3. Display the unique values in the 'City' column
unique_cities = df["City"].unique()
print("3. Display the unique values in the 'City' column:\n", unique_cities)
# Out:
# 3. Display the unique values in the 'City' column:
#  ['Alger' 'Setif' 'Oran' 'Annaba' 'Jijel']

# %%
# 4. Calculate the mean salary of the employees
mean_salary = df["Salary"].mean()
print("4. Calculate the mean salary of the employees:\n", mean_salary)
# Out:
# 4. Calculate the mean salary of the employees:
#  63000.0

# %%
# 5. Add a new column 'Bonus' with random bonus values (e.g., 1000, 1500, 1200, 2000, 1100)
df['Bonus'] = [1000, 1500, 1200, 2000, 1100]
print("5. Add a new column 'Bonus' with random bonus values:\n", df)
# Out:
# 5. Add a new column 'Bonus' with random bonus values:
#       Name   Age    City  Salary  Bonus
# 0   Amine   NaN   Alger   50000   1000
# 1   Imene  30.0   Setif   70000   1500
# 2  Yacine  22.0    Oran   60000   1200
# 3   Sarah  35.0  Annaba   80000   2000
# 4   Redha  28.0   Jijel   55000   1100

# %%
# 6. Drop the 'City' column from the DataFrame
df_without_city = df.drop(['City'], axis=1)
print("6. Drop the 'City' column from the DataFrame:\n", df_without_city)
# Out:
# 6. Drop the 'City' column from the DataFrame:
#       Name   Age  Salary  Bonus
# 0   Amine   NaN   50000   1000
# 1   Imene  30.0   70000   1500
# 2  Yacine  22.0   60000   1200
# 3   Sarah  35.0   80000   2000
# 4   Redha  28.0   55000   1100

# %%
# 7. Select only the rows where the age is greater than 25
above_25_years = df[df["Age"] > 25]
print("7. Select only the rows where the age is greater than 25:\n", above_25_years)
# Out:
# 7. Select only the rows where the age is greater than 25:
#      Name   Age    City  Salary  Bonus
# 1  Imene  30.0   Setif   70000   1500
# 3  Sarah  35.0  Annaba   80000   2000
# 4  Redha  28.0   Jijel   55000   1100

# %%
# 8. Set the 'Name' column as the index of the DataFrame
df_with_index = df.set_index("Name")
print("8. Set the 'Name' column as the index of the DataFrame:\n", df_with_index)
# Out:
# 8. Set the 'Name' column as the index of the DataFrame:
#           Age    City  Salary  Bonus
# Name
# Amine    NaN   Alger   50000   1000
# Imene   30.0   Setif   70000   1500
# Yacine  22.0    Oran   60000   1200
# Sarah   35.0  Annaba   80000   2000
# Redha   28.0   Jijel   55000   1100

# %%
# 9. Reset the index of the DataFrame
df_reset_index = df_with_index.reset_index()
print("9. Reset the index of the DataFrame:\n", df_reset_index)
# Out:
# 9. Reset the index of the DataFrame:
#       Name   Age    City  Salary  Bonus
# 0   Amine   NaN   Alger   50000   1000
# 1   Imene  30.0   Setif   70000   1500
# 2  Yacine  22.0    Oran   60000   1200
# 3   Sarah  35.0  Annaba   80000   2000
# 4   Redha  28.0   Jijel   55000   1100

# %%
# 10. Sort the DataFrame based on the 'Salary' column in descending order
sorted_df = df.sort_values("Salary", ascending=False)
print("10. Sort the DataFrame based on the 'Salary' column in descending order:\n", sorted_df)
# Out:
# 10. Sort the DataFrame based on the 'Salary' column in descending order:
#       Name   Age    City  Salary  Bonus
# 3   Sarah  35.0  Annaba   80000   2000
# 1   Imene  30.0   Setif   70000   1500
# 2  Yacine  22.0    Oran   60000   1200
# 4   Redha  28.0   Jijel   55000   1100
# 0   Amine   NaN   Alger   50000   1000

# %%
# 11. Group the DataFrame by the 'City' column and calculate the mean salary in each city
mean_salary_by_city = df.groupby('City')['Salary'].mean()
print("11. Group the DataFrame by the 'City' column and calculate the mean salary in each city:\n", mean_salary_by_city)
# Out:
# 11. Group the DataFrame by the 'City' column and calculate the mean salary in each city:
#  City
# Alger     50000.0
# Annaba    80000.0
# Jijel     55000.0
# Oran      60000.0
# Setif     70000.0
# Name: Salary, dtype: float64

# %%
# 12. Replace 'Yacine' with 'Selma' in the 'Name' column
df_replace_name = df['Name'].replace('Yacine', 'Selma')
print("12. Replace 'Charlie' with 'Eva' in the 'Name' column:\n", df_replace_name)
# Out:
# 12. Replace 'Charlie' with 'Eva' in the 'Name' column:
#  0    Amine
# 1    Imene
# 2    Selma
# 3    Sarah
# 4    Redha
# Name: Name, dtype: object

# %%
# 13. Display the statistical summary of the DataFrame
summary_stats = df.describe()
print("13. Display the statistical summary of the DataFrame:\n", summary_stats)
# Out:
# 13. Display the statistical summary of the DataFrame:
#               Age        Salary        Bonus
# count   4.000000      5.000000     5.000000
# mean   28.750000  63000.000000  1360.000000
# std     5.377422  12041.594579   403.732585
# min    22.000000  50000.000000  1000.000000
# 25%    26.500000  55000.000000  1100.000000
# 50%    29.000000  60000.000000  1200.000000
# 75%    31.250000  70000.000000  1500.000000
# max    35.000000  80000.000000  2000.000000

# %%
# 14. Fill missing values in the DataFrame with the mean of each column
df_filled_na = df.fillna(df.mean())
print("14. Fill missing values in the DataFrame with the mean of each column:\n", df_filled_na)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 2
#       1 # 14. Fill missing values in the DataFrame with the mean of each column
# ----> 2 df_filled_na = df.fillna(df.mean())
#       3 print("14. Fill missing values in the DataFrame with the mean of each column:\n", df_filled_na)
#
# File ~\PycharmProjects\data Mining Labs\.venv\Lib\site-packages\pandas\core\frame.py:11720, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11712 @doc(make_doc("mean", ndim=2))
#   11713 def mean(
#   11714     self,
#    (...)  11718     **kwargs,
#   11719 ):
# > 11720     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11721     if isinstance(result, Series):
#   11722         result = result.__finalize__(self, method="mean")
#
# File ~\PycharmProjects\data Mining Labs\.venv\Lib\site-packages\pandas\core\generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
#   12486         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12487     )
#
# File ~\PycharmProjects\data Mining Labs\.venv\Lib\site-packages\pandas\core\generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12438 nv.validate_func(name, (), kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File ~\PycharmProjects\data Mining Labs\.venv\Lib\site-packages\pandas\core\frame.py:11589, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11585     df = df.T
#   11587 # After possibly _get_data and transposing, we are now in the
#   11588 #  simple case where we can use BlockManager.reduce
# > 11589 res = df._mgr.reduce(blk_func)
#   11590 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11591 if out_dtype is not None and out.dtype != "boolean":
#
# File ~\PycharmProjects\data Mining Labs\.venv\Lib\site-packages\pandas\core\internals\managers.py:1519, in BlockManager.reduce(self, func)
#    1517 res_blocks: list[Block] = []
#    1518 for blk in self.blocks:
# -> 1519     nbs = blk.reduce(func)
#    1520     res_blocks.extend(nbs)
#    1522 index = Index([None])  # placeholder
#
# File ~\PycharmProjects\data Mining Labs\.venv\Lib\site-packages\pandas\core\internals\blocks.py:406, in Block.reduce(self, func)
#     400 @final
#     401 def reduce(self, func) -> list[Block]:
#     402     # We will apply the function and reshape the result into a single-row
#     403     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     404     assert self.ndim == 2
# --> 406     result = func(self.values)
#     408     if self.values.ndim == 1:
#     409         res_values = result
#
# File ~\PycharmProjects\data Mining Labs\.venv\Lib\site-packages\pandas\core\frame.py:11508, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11506         return np.array([result])
#   11507 else:
# > 11508     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File ~\PycharmProjects\data Mining Labs\.venv\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~\PycharmProjects\data Mining Labs\.venv\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~\PycharmProjects\data Mining Labs\.venv\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#     723     count = cast(np.ndarray, count)
#
# File ~\PycharmProjects\data Mining Labs\.venv\Lib\site-packages\pandas\core\nanops.py:1686, in _ensure_numeric(x)
#    1683 inferred = lib.infer_dtype(x)
#    1684 if inferred in ["string", "mixed"]:
#    1685     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1686     raise TypeError(f"Could not convert {x} to numeric")
#    1687 try:
#    1688     x = x.astype(np.complex128)
#
# TypeError: Could not convert ['AmineImeneYacineSarahRedha' 'AlgerSetifOranAnnabaJijel'] to numeric

# %%
# 15. Calculate the total salary expenditure by the company
total_salary_expenditure = df["Salary"].sum()
print("15. Calculate the total salary expenditure by the company:\n", total_salary_expenditure)
# Out:
# 15. Calculate the total salary expenditure by the company:
#  315000

# %%
# 16. Save the DataFrame to a CSV file named 'employee_data.csv'
df.to_csv("employee_data.csv", index=False)
print("16. Save the DataFrame to a CSV file named 'employee_data.csv': File saved.")
# Out:
# 16. Save the DataFrame to a CSV file named 'employee_data.csv': File saved.

# %%
# 17. Read the 'employee_data.csv' file into a new DataFrame
new_df = pd.read_csv("employee_data.csv")
print("17. Read the 'employee_data.csv' file into a new DataFrame:\n", new_df)
# Out:
# 17. Read the 'employee_data.csv' file into a new DataFrame:
#       Name   Age    City  Salary  Bonus
# 0   Amine   NaN   Alger   50000   1000
# 1   Imene  30.0   Setif   70000   1500
# 2  Yacine  22.0    Oran   60000   1200
# 3   Sarah  35.0  Annaba   80000   2000
# 4   Redha  28.0   Jijel   55000   1100

# %%
# 18. Display the last 2 rows of the new DataFrame
last_2_rows_new_df = new_df.tail(2)
print("18. Display the last 2 rows of the new DataFrame:\n", last_2_rows_new_df)
# Out:
# 18. Display the last 2 rows of the new DataFrame:
#      Name   Age    City  Salary  Bonus
# 3  Sarah  35.0  Annaba   80000   2000
# 4  Redha  28.0   Jijel   55000   1100

# %%
# 19. Rename the columns to 'EmployeeName', 'EmployeeAge', 'EmployeeCity', 'EmployeeSalary'
df_renamed_columns = df.rename(columns={
    'Name': 'EmployeeName',
    'Age': 'EmployeeAge',
    'City': 'EmployeeCity',
    'Salary': 'EmployeeSalary'
})
print("19. Rename the columns to 'EmployeeName', 'EmployeeAge', 'EmployeeCity', 'EmployeeSalary':\n", df_renamed_columns)
# Out:
# 19. Rename the columns to 'EmployeeName', 'EmployeeAge', 'EmployeeCity', 'EmployeeSalary':
#    EmployeeName  EmployeeAge EmployeeCity  EmployeeSalary  Bonus
# 0        Amine          NaN        Alger           50000   1000
# 1        Imene         30.0        Setif           70000   1500
# 2       Yacine         22.0         Oran           60000   1200
# 3        Sarah         35.0       Annaba           80000   2000
# 4        Redha         28.0        Jijel           55000   1100

# %%
# 20. Create a new DataFrame with only 'Name' and 'Salary' columns
df_name_salary = df[['Name' ,'Salary']]
print("20. Create a new DataFrame with only 'Name' and 'Salary' columns:\n", df_name_salary)
# Out:
# 20. Create a new DataFrame with only 'Name' and 'Salary' columns:
#       Name  Salary
# 0   Amine   50000
# 1   Imene   70000
# 2  Yacine   60000
# 3   Sarah   80000
# 4   Redha   55000
